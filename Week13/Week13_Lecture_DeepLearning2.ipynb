# %% [markdown]
# ![image.png](attachment:6be86a90-9b36-4a45-8634-bd54d22c679b.png)
# - Fully connecting
#     - Set some to 0%

# %% [markdown]
# - X (Signal)
# - H (Hidden)
# - H1 = <[x1, x2], [w1, w2]> = x1.w1 + x2.w2
#     - [x1, x2] = v1
#     - [w1, w2] = k (kernel)
